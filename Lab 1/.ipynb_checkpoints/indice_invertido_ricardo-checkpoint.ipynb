# %%
import pandas as pd
from nltk import word_tokenize
from collections import Counter
import sys

# %%
data = pd.read_csv("noticias_estadao.csv")

# %%
data.head()
# Out:
#                                               titulo  \
# 0     PT espera 30 mil pessoas em festa na Esplanada
# 1             Alckmin toma posse de olho no Planalto
# 2  Seis obstáculos e desafios do segundo mandato ...
# 3  Veja os desafios dos governadores que assumem ...
# 4  PT impulsiona cerimônia de posse da Dilma nas ...
#
#                                             conteudo  idNoticia
# 0  BRASÍLIA - Após o desgaste provocado com o lan...          1
# 1  Reeleito em outubro, o governador tucano Geral...          2
# 2    1. Rearranjo das contas A nova equipe econôm...          3
# 3  No Acre, governador reeleito quer erradicar an...          4
# 4  Os perfis da presidente Dilma Rousseff, nas re...          5

# %%
tokens_by_rows = data.apply(lambda row : set(word_tokenize(row["conteudo"].lower())), axis=1)

# %%
def create_vocab(data, tokens_by_rows):
    vocab_index = {}

    for i in range(len(tokens_by_rows)):
        for key in tokens_by_rows[i]:
            if key in vocab_index:
                vocab_index[key].append(data.at[i, 'idNoticia'])
            else:
                vocab_index[key] = [data.at[i, 'idNoticia']]
    return vocab_index

# %%
vocab_index = create_vocab(data, tokens_by_rows)

# %%
def get_token_less_docs(tokens, vocab_index):
    less_docs_size = sys.maxsize
    token_less_docs = None
    for token in tokens:
        if len(vocab_index[token]) < less_docs_size:
            less_docs_size = len(vocab_index[token])
            token_less_docs = token
    return token_less_docs

# %%
def get_documents_by_tokens(text, operator,vocab_index):
    
    tokens = word_tokenize(text)
    resp = []
    
    if operator == "and":
        
        token_less_docs = get_token_less_docs(tokens, vocab_index)
        tokens.remove(token_less_docs)
        
        smaller_list = get_documents_by_token(token_less_docs, vocab_index)
        lists_to_check = [get_documents_by_token(token, vocab_index) for token in tokens]
        
        for item in smaller_list:
            counter = 0
            for list_to_check in lists_to_check:
                if item not in list_to_check:
                    break
                else:
                    counter+=1
            if counter == len(lists_to_check):
                resp.append(item)       
            
    elif operator == "or":
        for token in tokens:
            print(token)
            print(get_documents_by_token(token, vocab_index))
        resp = list(set(sum([get_documents_by_token(token, vocab_index) for token in tokens], [])))
    
    return resp

# %%
def get_documents_by_token(token, vocab_index):
    try:
        resp = vocab_index[token]
    except:
        resp = []
    return resp

# %% [markdown]
# ## passando o operador como parâmetro

# %%
get_documents_by_tokens("dois brasil farinha", "and", vocab_index)
# Out:
# farinha
# [1, 2181, 2513, 3990, 4550, 5559, 7091, 7111, 7115, 7215]
# ['dois', 'brasil']
 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1457, 1460, 1461, 1479, 1484, 1487, 1489, 1490, 1491, 1503, 1505, 1506, 1507, 1508, 1514, 1520, 1521, 1522, 1523, 1525, 1527, 1536, 1537, 1538, 1549, 1551, 1552, 1559, 1566, 1570, 1571, 1581, 1582, 1583, 1586, 1588, 1589, 1595, 1598, 1600, 1611, 1613, 1615, 1620, 1624, 1626, 1627, 1629, 1630, 1636, 1637, 1640, 1641, 1646, 1657, 1658, 1660, 1661, 1662, 1674, 1675, 1676, 1690, 1692, 1693, 1694, 1695, 1696, 1700, 1703, 1718, 1719, 1721, 1722, 1723, 1724, 1728, 1729, 1730, 1733, 1734, 1737, 1739, 1740, 1744, 1746, 1762, 1770, 1774, 1786, 1787, 1788, 1791, 1792, 1794, 1797, 1799, 1805, 1812, 1813, 1815, 1818, 1819, 1820, 1822, 1824, 1825, 1826, 1832, 1833, 1836, 1842, 1843, 1850, 1854, 1855, 1857, 1858, 1860, 1862, 1866, 1867, 1868, 1869, 1873, 1878, 1880, 1883, 1884, 1886, 1888, 1890, 1893, 1906, 1907, 1908, 1909, 1910, 1911, 1915, 1919, 1921, 1922, 1923, 1924, 1926, 1935, 1941, 1943, 1944, 1950, 1953, 1954, 1956, 1960, 1961, 1963, 1964, 1965, 1978, 1982, 1987, 1988, 1989, 1990, 1992, 1993, 1994, 1995, 1996, 1997, 2000, 2001, 2002, 2004, 2007, 2009, 2011, 2018, 2020, 2022, 2025, 2026, 2029, 2032, 2033, 2034, 2036, 2040, 2043, 2044, 2047, 2048, 2049, 2050, 2053, 2058, 2059, 2060, 2061, 2064, 2065, 2070, 2071, 2075, 2081, 2082, 2084, 2088, 2092, 2094, 2095, 2100, 2105, 2109, 2110, 2119, 2120, 2123, 2125, 2126, 2127, 2131, 2141, 2142, 2143, 2144, 2146, 2147, 2149, 2152, 2154, 2155, 2156, 2158, 2167, 2171, 2173, 2175, 2181, 2182, 2185, 2189, 2191, 2194, 2195, 2197, 2213, 2214, 2219, 2220, 2230, 2232, 2236, 2240, 2250, 2251, 2256, 2258, 2266, 2271, 2272, 2274, 2 ...
# [4550, 7111]

# %%
def search(str_search, vocab_index):
    resp = []
    
    and_lists = str_search.split("OR")
    and_lists = [and_list.replace("AND", " ") for and_list in and_lists]
    
    for and_list in and_lists:
        resp.append(get_documents_by_tokens(and_list, "and", vocab_index))
    
    return list(set(sum(resp, [])))

# %% [markdown]
# ## Exemplos para teste

# %%
search("farinha", vocab_index)
# Out:
# [1, 2181, 4550, 7111, 7115, 7215, 2513, 7091, 3990, 5559]

# %%
search("politica", vocab_index)
# Out:
# [2819, 4803, 1030, 7431, 2255, 1168, 7183, 787, 4275, 891, 6013]

# %%
search("farinha AND politica", vocab_index)
# Out:
# []

# %%
search("brasil AND farinha OR politica", vocab_index)
# Out:
# [2819,
#  4803,
